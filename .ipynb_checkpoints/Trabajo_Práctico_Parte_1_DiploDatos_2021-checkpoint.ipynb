# %% [markdown]
# # TRABAJO PRÁCTICO ENTREGABLE - PARTE I
#
# ### INTEGRANTES DEL GRUPO IV:
# *   María Belén Acotto
# *   Elías Ferreyra
# *   Juan Ignacio Barrionuevo Galtier
# *   Oscar Alejandro Oviedo
# *   Gonzalo Heredia Edelstein
#
# ### CONSIGNAS
# **RESPONDER**:¿Cuáles son los lenguajes de programación asociados a los mejores salarios?
#
#
# **RESUMEN**: Para responder, se realiza una adecuación de los datos crudos, se analizan y procesan.
# Se trabaja principalmente con las variables "salary_monthly" y se correlacionan con los lenguajes de programación.

# %% [markdown]
# ## Carga de Datos

# %%
#Importo librerias
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats

seaborn.set_context('talk')

# %%
# El siguiente código setea la variable de pandas para poder ver todas las columnas
pd.set_option('display.max_columns', None)

# link URL
url = 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/sysarmy_survey_2020_processed.csv'
# generación del DataFrame (df) de trabajo
df = pd.read_csv(url)

# %% [markdown]
# ## Pre-Análisis

# %%
print('Información sobre las columnas del DATASET\n')

df.info()
# Out:
# Información sobre las columnas del DATASET
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6095 entries, 0 to 6094
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   profile_gender                                6095 non-null   object
#  1   profile_age                                   6095 non-null   int64
#  2   work_country                                  6095 non-null   object
#  3   work_province                                 6095 non-null   object
#  4   profile_years_experience                      6095 non-null   float64
#  5   work_years_in_company                         6095 non-null   float64
#  6   work_years_in_current_position                6095 non-null   float64
#  7   work_people_in_charge_of                      6095 non-null   int64
#  8   profile_studies_level                         6095 non-null   object
#  9   profile_studies_level_state                   6095 non-null   object
#  10  profile_career                                5796 non-null   object
#  11  profile_university                            5561 non-null   object
#  12  profile_specialization_courses                6095 non-null   object
#  13  profile_open_source_contributions             6095 non-null   object
#  14  profile_programming_as_hobby                  6095 non-null   object
#  15  work_role                                     6095 non-null   object
#  16  tools_platform                                6093 non-null   object
#  17  tools_programming_languages                   6094 non-null   object
#  18  tools_frameworks                              6094 non-null   object
#  19  tools_data_bases                              6093 non-null   object
#  20  tools_qa_testing                              6089 non-null   object
#  21  tools_IDEs                                    6094 non-null   object
#  22  tools_work_pc_os                              6095 non-null   object
#  23  tools_cellphone_os                            6095 non-null   object
#  24  work_on_call_duty                             6095 non-null   object
#  25  salary_on_call_duty_charge                    6095 non-null   float64
#  26  work_on_call_duty_charge_type                 6095 non-null   object
#  27  work_contract_type                            6095 non-null   object
#  28  salary_monthly_BRUTO                          6095 non-null   float64
#  29  salary_monthly_NETO                           5883 non-null   float64
#  30  salary_in_usd                                 676 non-null    object
#  31  salary_satisfaction                           6095 non-null   int64
#  32  salary_comparison_last_semester               6095 non-null   int64
#  33  salary_has_bonus                              6095 non-null   object
#  34  salary_bonus_tied_to                          6095 non-null   object
#  35  salary_inflation_adjustment_2020              6095 non-null   object
#  36  salary_percentage_inflation_adjustment_2020   6095 non-null   float64
#  37  salary_month_last_inflation_adjustment        6095 non-null   int64
#  38  work_has_violence_situations                  5954 non-null   object
#  39  profile_sexual_orientation                    5912 non-null   object
#  40  profile_has_disabilities                      600 non-null    object
#  41  profile_has_disabilities_hiring_difficulties  2207 non-null   object
#  42  company_employee_number                       6095 non-null   object
#  43  company_main_activity                         6095 non-null   object
#  44  company_recommended                           6095 non-null   int64
#  45  company_diversity_policies                    6095 non-null   int64
#  46  company_extra_benefits                        6094 non-null   object
#  47  company_best_companies_city                   1692 non-null   object
# dtypes: float64(7), int64(7), object(34)
# memory usage: 2.2+ MB

# %% [markdown]
# Como podemos observar, tenemos **48 columnas**, con tres tipos de datos:
# * float
# * int
# * object

# %% [markdown]
# ### Primera vista de los datos

# %%
df.head()
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 0          Mujer           26    Argentina  Ciudad Autónoma de Buenos Aires
# 1         Hombre           29    Argentina                       Corrientes
# 2          Mujer           22    Argentina  Ciudad Autónoma de Buenos Aires
# 3         Hombre           39    Argentina                       Corrientes
# 4         Hombre           32    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
# 1                       5.0                    2.0
# 2                       2.0                    0.0
# 3                      15.0                   15.0
# 4                       9.0                    6.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
# 1                             2.0                         4
# 2                             0.0                         0
# 3                            13.0                         5
# 4                             6.0                         0
#
#   profile_studies_level profile_studies_level_state  \
# 0         Universitario                    En curso
# 1         Universitario                    En curso
# 2            Secundario                  Completado
# 3              Posgrado                  Incompleto
# 4         Universitario                    En curso
#
#                               profile_career  \
# 0      Ingeniería en Sistemas de Información
# 1      Ingeniería en Sistemas de Información
# 2                                        NaN
# 3                   Licenciatura en Sistemas
# 4  Licenciatura en Ciencias dela Computación
#
#                        profile_university  \
# 0  UTN - Universidad Tecnológica Nacional
# 1  UTN - Universidad Tecnológica Nacional
# 2                                     NaN
# 3  UNNE Universidad Nacional del Nordeste
# 4       UBA - Universidad de Buenos Aires
#
#                       profile_specialization_courses  \
# 0                          Sí, los pagó un empleador
# 1  Sí, de forma particular, Sí, los pagó un emple...
# 2  Sí, de forma particular, Sí, los pagó un emple...
# 3  Sí, de forma particular, Sí, los pagó un emple...
# 4                                                 No
#
#   profile_open_source_contributions profile_programming_as_hobby  \
# 0                                No                           Sí
# 1                                No                           Sí
# 2                                No                           Sí
# 3                                Sí                           Sí
# 4                                No                           Sí
#
#                  work_role                                    tools_platform  \
# 0               Consultant                                           Ninguna
# 1                Developer          Docker, Google Cloud Platform/App Engine
# 2                  Infosec                                     Linux, VMWare
# 3  SysAdmin / DevOps / SRE  Docker, Linux, OpenStack, VMWare, Windows Server
# 4                Developer                               Amazon Web Services
#
#                          tools_programming_languages   tools_frameworks  \
# 0                                            Ninguno            Ninguno
# 1                           HTML, Javascript, Python     Django, jQuery
# 2                                            Ninguno            Ninguno
# 3  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...  jQuery, WordPress
# 4             CSS, HTML, Javascript, SQL, TypeScript   Angular, Node.js
#
#                   tools_data_bases tools_qa_testing  \
# 0                          Ninguna          Ninguna
# 1      Informix, MySQL, PostgreSQL          Ninguna
# 2                          Ninguna          Ninguna
# 3      Microsoft SQL Server, MySQL          PHPUnit
# 4  Amazon DynamoDB, MongoDB, MySQL             Jest
#
#                                           tools_IDEs tools_work_pc_os  \
# 0                                            Ninguno        GNU/Linux
# 1  IPython / Jupyter, Sublime Text, Visual Studio...        GNU/Linux
# 2                                            Ninguno          Windows
# 3                        Eclipse, Visual Studio Code        GNU/Linux
# 4                                                Vim            macOS
#
#   tools_cellphone_os work_on_call_duty  salary_on_call_duty_charge  \
# 0            Android                No                         0.0
# 1            Android                No                         0.0
# 2                iOS                No                         0.0
# 3            Android        Sí, pasiva                         0.0
# 4            Android                No                         0.0
#
#   work_on_call_duty_charge_type work_contract_type  salary_monthly_BRUTO  \
# 0                         Bruto          Full-Time               53000.0
# 1                         Bruto          Full-Time               79000.0
# 2       Porcentaje de mi sueldo          Full-Time              160000.0
# 3                         Bruto          Full-Time              130000.0
# 4       Porcentaje de mi sueldo          Full-Time              140000.0
#
#    salary_monthly_NETO salary_in_usd  salary_satisfaction  \
# 0              43000.0           NaN                    1
# 1              63000.0           NaN                    2
# 2             127000.0           NaN                    3
# 3             102000.0           NaN                    3
# 4             106000.0           NaN                    1
#
#    salary_comparison_last_semester    salary_has_bonus  \
# 0                                1                  No
# 1                                2  Menos de un sueldo
# 2                                3           Un sueldo
# 3                                1                  No
# 4                                1  Menos de un sueldo
#
#          salary_bonus_tied_to salary_inflation_adjustment_2020  \
# 0              No recibo bono                               No
# 1  Performance de la compañía                              Uno
# 2      Performance individual                               No
# 3              No recibo bono                               No
# 4      Performance individual                               No
#
#    salary_percentage_inflation_adjustment_2020  \
# 0                                          0.0
# 1                                         10.0
# 2                                          0.0
# 3                                          0.0
# 4                                          0.0
#
#    salary_month_last_inflation_adjustment work_has_violence_situations  \
# 0                                       0         En mi trabajo actual
# 1                                       1                        Jamás
# 2                                       0       En un trabajo anterior
# 3                                       0         En mi trabajo actual
# 4                                       0                        Jamás
#
#   profile_sexual_orientation profile_has_disabilities  \
# 0                 Homosexual                      NaN
# 1               Heterosexual                   Visual
# 2           Bisexual o queer                      NaN
# 3               Heterosexual                      NaN
# 4               Heterosexual                      NaN
#
#   profile_has_disabilities_hiring_difficulties company_employee_number  \
# 0                                          NaN                501-1000
# 1                                           No                 201-500
# 2                                           No               2001-5000
# 3                                          NaN                501-1000
# 4                                          NaN                   11-50
#
#                            company_main_activity  company_recommended  \
# 0  Servicios / Consultoría de Software / Digital                    7
# 1                               Otras industrias                    8
# 2                               Otras industrias                    6
# 3                               Otras industrias                    7
# 4  Servicios / Consultoría de Software / Digital                    6
#
#    company_diversity_policies  \
# 0                           2
# 1                           9
# 2                           9
# 3                           6
# 4                           6
#
#                               company_extra_benefits  \
# 0  Capacitaciones y/o cursos, Comidas pagas / sub...
# 1  Horarios flexibles, Stock options / RSUs, Viát...
# 2  Clases de gimnasia online, Comidas pagas / sub...
# 3  Abono de celular, Capacitaciones y/o cursos, C...
# 4  Clases de idiomas, Horarios flexibles, Vacacio...
#
#   company_best_companies_city
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %% [markdown]
# ### Mapa de Calor para análisis lijero sobre correlatividad entre columnas

# %%
#Agrego mapa de calor
seaborn.heatmap(df.corr());

# %% [markdown]
# #### Observaciones

# %% [markdown]
# > * La diagonal principal está en colores más claros (mejor correlatividad) ya que es 1, lo cual nos centramos en las columnas con colores más claros, excluyendo la matriz identidad.

# %% [markdown]
# ### Análisis de correlatividad sobre la variable de salary_monthly_BRUTO.

# %%
corr = df.corr()
corr[['salary_monthly_BRUTO']].sort_values(by = 'salary_monthly_BRUTO',ascending = False)\
.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row0_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row1_col0{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row2_col0{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row3_col0{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row4_col0{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row5_col0{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row6_col0{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row7_col0{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row8_col0{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row9_col0{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row10_col0{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row11_col0{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row12_col0,#T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row13_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >salary_monthly_BRUTO</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row0" class="row_heading level0 row0" >salary_monthly_BRUTO</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row1" class="row_heading level0 row1" >salary_monthly_NETO</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row1_col0" class="data row1 col0" >0.833335</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row2" class="row_heading level0 row2" >salary_satisfaction</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row2_col0" class="data row2 col0" >0.344676</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row3" class="row_heading level0 row3" >salary_comparison_last_semester</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row3_col0" class="data row3 col0" >0.331435</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row4" class="row_heading level0 row4" >profile_years_experience</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row4_col0" class="data row4 col0" >0.250545</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row5" class="row_heading level0 row5" >company_recommended</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row5_col0" class="data row5 col0" >0.196381</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row6" class="row_heading level0 row6" >salary_on_call_duty_charge</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row6_col0" class="data row6 col0" >0.149794</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row7" class="row_heading level0 row7" >company_diversity_policies</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row7_col0" class="data row7 col0" >0.115718</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row8" class="row_heading level0 row8" >work_people_in_charge_of</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row8_col0" class="data row8 col0" >0.101176</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row9" class="row_heading level0 row9" >work_years_in_current_position</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row9_col0" class="data row9 col0" >0.039366</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row10" class="row_heading level0 row10" >work_years_in_company</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row10_col0" class="data row10 col0" >0.019175</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row11" class="row_heading level0 row11" >salary_percentage_inflation_adjustment_2020</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row11_col0" class="data row11 col0" >0.010695</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row12" class="row_heading level0 row12" >profile_age</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row12_col0" class="data row12 col0" >-0.006752</td>
#             </tr>
#             <tr>
#                         <th id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002level0_row13" class="row_heading level0 row13" >salary_month_last_inflation_adjustment</th>
#                         <td id="T_6bd04dac_d5b6_11eb_a81c_0242ac1c0002row13_col0" class="data row13 col0" >-0.009646</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Observaciones

# %% [markdown]
# > * Al ver los datos del dataset, las correlatividades de forma rápida, llegamos a tomar las siguientes columnas como columnas relevantes

# %%
# Columnas del DF relevantes para el analisis
relevant_columns = ['work_contract_type','work_role','tools_programming_languages','salary_monthly_BRUTO', 'salary_monthly_NETO',
                    'profile_years_experience','work_years_in_company','work_years_in_current_position','work_people_in_charge_of']

# %% [markdown]
# ### Valores Nulos

# %%
# Cuantificación de datos vacios/NAN de columnas relevantes
print(len(df))
for s in relevant_columns:
  print(s,len(df[pd.isnull(df[s])]))
# Out:
# 6095
# work_contract_type 0
# work_role 0
# tools_programming_languages 1
# salary_monthly_BRUTO 0
# salary_monthly_NETO 212
# profile_years_experience 0
# work_years_in_company 0
# work_years_in_current_position 0
# work_people_in_charge_of 0

# %% [markdown]
# #### Observaciones

# %% [markdown]
# > * Dado los datos faltantes en la columna "salary_monthly_NETO", se trabajará con la variable "salary_monthly_BRUTO".
#
# > * Se eliminará la fila faltante en "tools_programming_languages" y además, los que colocaron la opción "Ninguno" y otros datos que ensucian el dataset. Con esto solo se considera, aquellos que conocen algún programa.

# %% [markdown]
# ## Primera Limpieza de Datos

# %%
# Eliminación de la fila con el valor nulo
df = df[df['tools_programming_languages'].notnull()]

# %% [markdown]
# Rápidamente, vemos datos o lenguajes a considerar para ser eliminados.

# %%
lenguajes = pd.DataFrame()
lenguajes['name'] = df.tools_programming_languages.str.split(',', expand=True).stack().to_list()
lenguajes['name'] = lenguajes['name'].str.strip()
lenguajes = lenguajes.drop_duplicates(subset=['name'])
lenguajes.sort_values(by='name')
# Out:
#                           name
# 4616                         -
# 14168                        .
# 47                        .NET
# 16315  .NET no es un lenguaje!
# 628                        4gl
# ...                        ...
# 9982              visual basic
# 7713            visual fox pro
# 15380                      xml
# 4098                xsl y xml.
# 17855                     yaml
#
# [205 rows x 1 columns]

# %% [markdown]
# Sacamos aquellos fáciles de identificar luego de varias pruebas

# %%
df = df[~df.tools_programming_languages.str.lower().str.contains("ningun")==True]
df = df[~df.tools_programming_languages.str.lower().str.contains("aplica")==True]
df = df[~df.tools_programming_languages.str.lower().str.contains("no es")==True]
df = df[df.tools_programming_languages != '.']
df = df[df.tools_programming_languages != '-']

# %% [markdown]
# ## Análisis y procesos sobre la variable "salary_monthly_BRUTO"

# %%
max_SMB = 300000
sub_df = df[df["salary_monthly_BRUTO"] < max_SMB]
fig, ax = plt.subplots(figsize=(15,8))
seaborn.histplot(data=sub_df, x="salary_monthly_BRUTO", kde=True, bins=100, color='red', stat= 'density')
plt.xlabel('Salario Mensual Bruto')
plt.title('Análisis sobre \"salary_monthly_BRUTO\"',fontsize=16)
plt.show()

# %% [markdown]
# ### Análisis

# %% [markdown]
# #### Observaciones

# %% [markdown]
# > * La dendidad muestra una función asimétrica, desplazada hacia valores más positivos. Es muy extendida, con valores de salario bruto muy altos. Por lo cual se filtrarán estos datos, utilizando el criterio del tercer cuartil (2.5 valores por encima).

# %% [markdown]
# > * La densidad muestra un no esperable máximo local a bajo valores de salario (cercano a 0). Se filtrarán aquellos salarios menores a 1000 $AR.
# Valor elegido aleatoriamente

# %% [markdown]
# ### Filtrado de Datasets

# %% [markdown]
# #### Creación de funciones filtros

# %%
# filtro valores
def clean_outliers_q3(dataset, column_name):
  # Returns dataset removing the outlier rows form columns @column_name
  interesting_col = dataset[column_name]
  # Here we can remove the outliers from both ends, or even add more restrictions.
  mask_outlier = (interesting_col <= (2.5 * interesting_col.quantile(.75)))
  return dataset[mask_outlier]

def clean_cero(dataset, column_name, val):
  interesting_col = dataset[column_name]
  mask_outlier = (interesting_col >= val)
  return dataset[mask_outlier]

# %% [markdown]
# #### Filtrar valores mínimos (ceros) y filtro con criterio del tercer cuartil

# %%
salary_col = "salary_monthly_BRUTO"
valor = 1000.0
fig = plt.figure(figsize=(16, 8))
df_filtered = clean_outliers_q3(df, salary_col)
df_filtered2 = clean_cero(df_filtered, salary_col, valor)
seaborn.histplot(data=df_filtered2, x="salary_monthly_BRUTO", kde=True, bins=100, color='red', stat= 'density')
plt.title('Distribución del Salario Mensual Bruto (Filtrado)',fontsize=16)
plt.xlabel('Salario Mensual Bruto')
plt.show()

# %% [markdown]
# ### Comparativa con una distribución Normal (Gausiana)

# %%
fig, axes = plt.subplots(1, 2,figsize=(24,11))
seaborn.distplot(df_filtered2['salary_monthly_BRUTO'], fit = norm, ax=axes[0])
res = stats.probplot(df_filtered2['salary_monthly_BRUTO'], plot = plt)
fig.suptitle('Distribución Normal (Gausiana) - Salario Bruto', fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Simulación de una distribucion normal:

# %% [markdown]
# Como no logramos una perfecta distribución normal, lo que optamos por hacer, fue calcular el logaritmo de nuestra variable "salary_monthly_BRUTO" y dibujar la normal de esta manera

# %%
# Transformación de los datos para que parezca una distribucion normal:

df_filtered3 = np.log(df_filtered2['salary_monthly_BRUTO'])
fig, axes = plt.subplots(1, 2,figsize=(24,8))
seaborn.distplot(df_filtered3, fit = norm, ax=axes[0])
res = stats.probplot(df_filtered3, plot = plt)
fig.suptitle('Distribución Normal (Gausiana) - Logarítmo del Salario Bruto', fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Observaciones

# %% [markdown]
# > * Los datos filtrados y re-normalizados presentan una distribución normal. Sin embargo fuertes desviaciones todavía son observadas para valores pequeños de los salarios.

# %% [markdown]
# ## Análisis y procesos sobre la variable "tools_programming_languages"

# %% [markdown]
# Descripciones sobre nuestra variable

# %%
print(df_filtered2.salary_monthly_BRUTO.describe())
print('Mediana:', df_filtered2.salary_monthly_BRUTO.median())
print('Moda:',df_filtered2.salary_monthly_BRUTO.mode())
# Out:
# count      4763.000000
# mean     112802.170021
# std       66156.689257
# min        1100.000000
# 25%       65000.000000
# 50%      100000.000000
# 75%      141941.000000
# max      370000.000000
# Name: salary_monthly_BRUTO, dtype: float64
# Mediana: 100000.0
# Moda: 0    100000.0
# dtype: float64

# %% [markdown]
# Nos concentramos sobre los valores que se encuentran dentro del cuarto cuartil, es decir, "los que ganan más"

# %%
auxdf = df_filtered2["salary_monthly_BRUTO"]
fig = plt.figure(figsize=(12, 6))
seaborn.boxplot(auxdf, color='red')
plt.title('Disttribución Salario Bruto (Filtrado)',fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Función que nos ayuda a separar los distintos lenguajes de programación

# %%
# Función que recorrerá una culumna, y nos separará los lenguajes agrupados
def split_languages(languages_str):
  if not isinstance(languages_str, str):
    return []
  
  # Split string dentro de la lista de items y borramos las comas y espacios.
  return [lang.strip().replace(',', '')
          for lang in languages_str.split()]

# %%
lenguajes = pd.DataFrame()
lenguajes['name'] = df.tools_programming_languages.str.split(',', expand=True).stack().to_list()
lenguajes['name'] = lenguajes['name'].str.strip()
lenguajes = lenguajes.drop_duplicates(subset=['name'])
lenguajes.sort_values(by='name')
# Out:
#                  name
# 45               .NET
# 596               4gl
# 97               ABAP
# 4280             APEX
# 1341     ActionScript
# ...               ...
# 9467     visual basic
# 7330   visual fox pro
# 14584             xml
# 3942       xsl y xml.
# 16869            yaml
#
# [191 rows x 1 columns]

# %% [markdown]
# Creamos una nueva columna dentro del dataset tratado con el lenguaje de programación

# %%
# Create a new column with the list of languages
df_filtered2['cured_programming_languages'] = df_filtered2.tools_programming_languages.apply(split_languages).values
if 'cured_programming_languages' not in relevant_columns:
    relevant_columns.append('cured_programming_languages') 

# En esta sección, multiplicaremos cada fila por la cantidad de lenguajes que tiene cada usuario
# Para no duplicar información necesaria, crearemos una nueva columna para separar cada lenguaje
df_lang = df_filtered2.cured_programming_languages.apply(pd.Series).stack()\
    .reset_index(level=-1, drop=True).to_frame().join(df_filtered2[relevant_columns])\
    .rename(columns={0: 'programming_language'})

df_lang = df_lang.iloc[:, :-1] # Valores Sin la columna 'cured_programming_languages'
df_lang[:5]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   programming_language work_contract_type                work_role  \
# 1                 HTML          Full-Time                Developer
# 1           Javascript          Full-Time                Developer
# 1               Python          Full-Time                Developer
# 3           Bash/Shell          Full-Time  SysAdmin / DevOps / SRE
# 3                    C          Full-Time  SysAdmin / DevOps / SRE
#
#                          tools_programming_languages  salary_monthly_BRUTO  \
# 1                           HTML, Javascript, Python               79000.0
# 1                           HTML, Javascript, Python               79000.0
# 1                           HTML, Javascript, Python               79000.0
# 3  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...              130000.0
# 3  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...              130000.0
#
#    salary_monthly_NETO  profile_years_experience  work_years_in_company  \
# 1              63000.0                       5.0                    2.0
# 1              63000.0                       5.0                    2.0
# 1              63000.0                       5.0                    2.0
# 3             102000.0                      15.0                   15.0
# 3             102000.0                      15.0                   15.0
#
#    work_years_in_current_position  work_people_in_charge_of
# 1                             2.0                         4
# 1                             2.0                         4
# 1                             2.0                         4
# 3                            13.0                         5
# 3                            13.0                         5

# %%
df_filtered2['cured_programming_languages']
# Out:
# 1                              [HTML, Javascript, Python]
# 3       [Bash/Shell, C, CSS, HTML, Java, Javascript, P...
# 4                [CSS, HTML, Javascript, SQL, TypeScript]
# 5                                      [Java, Javascript]
# 6                                            [Javascript]
#                               ...
# 6087                                             [Python]
# 6088                                               [HTML]
# 6089                            [Bash/Shell, Python, SQL]
# 6090    [.NET, C#, COBOL, CSS, HTML, Javascript, PHP, ...
# 6093    [C, C++, HTML, Java, Javascript, PHP, Python, ...
# Name: cured_programming_languages, Length: 4763, dtype: object

# %% [markdown]
# Contabilizamos la cantidad de veces que aparecen cada lenguaje

# %%
# contador de lenguajes
language_count = df_lang.programming_language.value_counts()\
    .reset_index().rename(columns={'index': 'language', 'programming_language': 'frequency'})
#language_count[:11]
language_count = language_count.sort_values(by=['frequency'], ascending=False)
language_count
# Out:
#          language  frequency
# 0      Javascript       2340
# 1             SQL       2032
# 2            HTML       1739
# 3          Python       1380
# 4            Java       1375
# ..            ...        ...
# 116           lex          1
# 115        Pascal          1
# 114            tf          1
# 113  lenguaje!!!!          1
# 208          Mule          1
#
# [209 rows x 2 columns]

# %%
language_count.language.values
# Out:
# array(['Javascript', 'SQL', 'HTML', 'Python', 'Java', 'CSS', 'Bash/Shell',
#        'PHP', '.NET', 'TypeScript', 'C#', 'Go', 'C++', 'C', 'VBA',
#        'Kotlin', 'Groovy', 'Ruby', 'Scala', 'Swift', 'R', 'COBOL', 'ABAP',
#        'Perl', 'Objective-C', 'Delphi', 'Dart', 'ActionScript',
#        'Assembler', 'Powershell', 'Matlab', 'Apex', 'Smalltalk', 'Rust',
#        'PL/SQL', 'Genexus', 'Elixir', 'PowerShell', 'Visual', 'Erlang',
#        'Clojure', 'SAS', '/', 'visual', 'Basic', 'Plsql', 'VB6', '6',
#        'Clarion', 'Powerbuilder', 'Power', 'JSON', 'RPA', 'no', 'YAML',
#        'VB', '4gl', 'ESQL', 'powershell', 'Script', 'SCSS', 'Solidity',
#        'APEX', 'Builder', 'Progress', 'XML', 'DAX', 'y', 'progress',
#        'Lua', 'FoxPro', 'Jcl', 'Mikrotik', 'de', 'Qlik', 'Oracle', 'No',
#        'vb6', 'PowerBuilder', 'rexx', 'Adabas', 'Blueprints', 'Tibco',
#        'GraphQL', 'es', 'Ladder', 'Dell', 'bi', 'shell', 'xml', 'SOAP',
#        'openedge', 'robin', 'Fortran', 'FOXPRO2.5', 'vb', 'Siebel',
#        'GOSU', 'Windev', 'GeneXus', 'power', 'MEL', 'Json', 'Ansible',
#        'Blue', 'pl/sql', 'solidity', 'PowerCLI', 'XSLT', 'Powersheell',
#        'Lenguaje', 'Nativescrip', 'Infobasic', 'Mulesoft', '-',
#        'HackLang', 'Nim', 'ansible', 'Cliper', 'bash', 'programo',
#        'Google', 'Vb6', 'en', 'Appeon', 'Jbase', 'script', 'powerscript',
#        'un', 'salesforce', 'Pl/sql', 'Gosu', 'Arduino', 'Boomi',
#        'Salesforce', 'Xamarin', 'Prism', 'RegEx', '6.0', 'META4', 'Kdb',
#        'VFP', 'SOQL', 'Unreal)', 'Pl-sql', 'soy', 'Deluge', 'TAL',
#        'Biztalk', 'cliente', 'twig', 'VB5', 'POWERBUILDER', 'OpenEdge',
#        'essbase', 'Svelte', 'Coldfusion', 'json', 'Plataforma',
#        'vbscript', 'DB', 'lenguajes', 'X++', 'son', 'Sql', '|', 'code',
#        'Unity', 'Basico', 'Verilog', '(programación', 'net', 'Asp',
#        'NoSQL', 'OAC', 'Yacc', 'terraform', 'QVX', 'CG/HLSL', 'MongoDB',
#        'del', 'Typescript', 'Graphql', 'vhdl', 'fox', 'recruiter',
#        'foxpro', 'pro', 'yaml', 'sass', 'basic', 'programación',
#        'PeopleSoft', 'PLC', 'Natural', 'M', 'plsql', 'low', 'React',
#        'Apps', 'Clipper', 'JCL', 'hyperion', 'Propio', 'lex', 'Pascal',
#        'tf', 'lenguaje!!!!', 'Mule'], dtype=object)

# %%
lenguajes_relevantes = ['Javascript','Python','Java','PHP','.NET','TypeScript','C#','C++','C','VBA','Kotlin','Ruby']

# %%
df_lang2 = df_lang[df_lang['programming_language'].apply(lambda x: any(valor for valor in lenguajes_relevantes if valor in x))]
df_lang2
# Out:
#      programming_language work_contract_type                work_role  \
# 1              Javascript          Full-Time                Developer
# 1                  Python          Full-Time                Developer
# 3                       C          Full-Time  SysAdmin / DevOps / SRE
# 3                     CSS          Full-Time  SysAdmin / DevOps / SRE
# 3                    Java          Full-Time  SysAdmin / DevOps / SRE
# ...                   ...                ...                      ...
# 6093                  C++          Full-Time  SysAdmin / DevOps / SRE
# 6093                 Java          Full-Time  SysAdmin / DevOps / SRE
# 6093           Javascript          Full-Time  SysAdmin / DevOps / SRE
# 6093                  PHP          Full-Time  SysAdmin / DevOps / SRE
# 6093               Python          Full-Time  SysAdmin / DevOps / SRE
#
#                             tools_programming_languages  salary_monthly_BRUTO  \
# 1                              HTML, Javascript, Python               79000.0
# 1                              HTML, Javascript, Python               79000.0
# 3     Bash/Shell, C, CSS, HTML, Java, Javascript, PH...              130000.0
# 3     Bash/Shell, C, CSS, HTML, Java, Javascript, PH...              130000.0
# 3     Bash/Shell, C, CSS, HTML, Java, Javascript, PH...              130000.0
# ...                                                 ...                   ...
# 6093   C, C++, HTML, Java, Javascript, PHP, Python, SQL               86000.0
# 6093   C, C++, HTML, Java, Javascript, PHP, Python, SQL               86000.0
# 6093   C, C++, HTML, Java, Javascript, PHP, Python, SQL               86000.0
# 6093   C, C++, HTML, Java, Javascript, PHP, Python, SQL               86000.0
# 6093   C, C++, HTML, Java, Javascript, PHP, Python, SQL               86000.0
#
#       salary_monthly_NETO  profile_years_experience  work_years_in_company  \
# 1                 63000.0                       5.0                    2.0
# 1                 63000.0                       5.0                    2.0
# 3                102000.0                      15.0                   15.0
# 3                102000.0                      15.0                   15.0
# 3                102000.0                      15.0                   15.0
# ...                   ...                       ...                    ...
# 6093                 72.0                       5.0                    3.0
# 6093                 72.0                       5.0                    3.0
# 6093                 72.0                       5.0                    3.0
# 6093                 72.0                       5.0                    3.0
# 6093                 72.0                       5.0                    3.0
#
#       work_years_in_current_position  work_people_in_charge_of
# 1                                2.0                         4
# 1                                2.0                         4
# 3                               13.0                         5
# 3                               13.0                         5
# 3                               13.0                         5
# ...                              ...                       ...
# 6093                             2.0                         0
# 6093                             2.0                         0
# 6093                             2.0                         0
# 6093                             2.0                         0
# 6093                             2.0                         0
#
# [10406 rows x 10 columns]

# %% [markdown]
# #### Obeservaciones

# %% [markdown]
# > * Se analizarán la correlación con los 11 lenguajes más utilizados en 2020 y que tengan mayor frecuencia encontradas en las respuestas.
#
# > * Se adicionarán otros filtros, para aquellas personas **full-time** y que sean **Desarrolladores**

# %% [markdown]
# ### Procesos sobre lenguajes más usados

# %% [markdown]
# Preparación de Filtros

# %%
# Filtrado de lenguajes relevantes
#interesting_languages = language_count.iloc[:10,0].values.tolist()
interesting_languages = lenguajes_relevantes
# Filtrado de personas Full-Time
interesting_people = ["Full-Time"]
# Filtrado para aquellos que se denominaron como Desarrolladores
isDeveloper = ["Developer"]

# %% [markdown]
# Proceso de filtrado

# %%
filtered_df_lang = df_lang2[df_lang2.programming_language.isin(interesting_languages)]
filtered_df_lang = filtered_df_lang[filtered_df_lang.work_contract_type.isin(interesting_people)]
filtered_df_lang = filtered_df_lang[filtered_df_lang.work_role.isin(isDeveloper)]
filtered_df_lang[:5]
# Out:
#   programming_language work_contract_type  work_role  \
# 1           Javascript          Full-Time  Developer
# 1               Python          Full-Time  Developer
# 4           Javascript          Full-Time  Developer
# 4           TypeScript          Full-Time  Developer
# 5                 Java          Full-Time  Developer
#
#               tools_programming_languages  salary_monthly_BRUTO  \
# 1                HTML, Javascript, Python               79000.0
# 1                HTML, Javascript, Python               79000.0
# 4  CSS, HTML, Javascript, SQL, TypeScript              140000.0
# 4  CSS, HTML, Javascript, SQL, TypeScript              140000.0
# 5                        Java, Javascript               54000.0
#
#    salary_monthly_NETO  profile_years_experience  work_years_in_company  \
# 1              63000.0                       5.0                    2.0
# 1              63000.0                       5.0                    2.0
# 4             106000.0                       9.0                    6.0
# 4             106000.0                       9.0                    6.0
# 5              44000.0                       1.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of
# 1                             2.0                         4
# 1                             2.0                         4
# 4                             6.0                         0
# 4                             6.0                         0
# 5                             0.0                         0

# %% [markdown]
# #### Observaciones

# %% [markdown]
# > * Como hemos filtrado nuestro conjunto de datos, volveremos a hacer un conteo de la frecuencia de los mismos
# > * Notarán, que al bajar la cantidad de filas (población), baja la frecuencia de cada valor.

# %%
# contador de lenguajes luego de los filtros
language_count = filtered_df_lang.programming_language.value_counts()\
    .reset_index().rename(columns={'index': 'programming_language', 'programming_language': 'frequency'})
language_count
# Out:
#    programming_language  frequency
# 0            Javascript       1228
# 1                  Java        647
# 2            TypeScript        440
# 3                  .NET        374
# 4                    C#        360
# 5                   PHP        307
# 6                Python        289
# 7                Kotlin         98
# 8                   C++         67
# 9                   VBA         59
# 10                    C         57
# 11                 Ruby         32

# %% [markdown]
# > * A su vez, lo hemos explayado en un gráfico de barras ordenado por el lenguaje más usado en nuestra muestra

# %%
# Gráfico de barra: # vs language
fig = plt.figure(figsize=(10,8))
seaborn.countplot(data=filtered_df_lang, x='programming_language', color = "red", order = filtered_df_lang['programming_language'].value_counts().index) 
plt.xticks(rotation=45)
plt.ylabel("Frecuencia de apariciones")
plt.xlabel("Lenguaje")
plt.title('Top Lenguajes de Programación',fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ## Salario Vs Lenguaje de Programación

# %% [markdown]
# ### Procesos sobre ambas variables

# %% [markdown]
# Agrupamos por lenguaje y estimación de la mediana del salario de Programadores Full-Time

# %%
salary_col = 'salary_monthly_BRUTO'
group_col = 'programming_language'
df_aux = filtered_df_lang[[group_col, salary_col]].groupby(group_col).median()
#df_aux = filtered_df_lang[[group_col, salary_col]].groupby(group_col).mean()

# %% [markdown]
# ## Primera visualización

# %% [markdown]
# A continuación, veremos la primer visualización de los lenguajes más usados vs
# la mediana del salario bruto

# %%
fig = plt.figure(figsize=(12,7))
seaborn.lineplot(data=df_aux)
plt.xticks(rotation=45)
plt.title('Mediana de los Sueldos vs Lenguajes de Programación',fontsize=16)
plt.show()

# %% [markdown]
# ### Visualización de los Lenguajes de Programación mejores pagos

# %%
Marge_df = pd.merge(language_count, df_aux, on='programming_language')
Marge_df
seaborn.set_theme(style="whitegrid")

cmap = seaborn.cubehelix_palette(rot=-.2, as_cmap=True)
g = seaborn.relplot(
    data=Marge_df,
    x="programming_language", y='salary_monthly_BRUTO',
     hue="frequency", size = "frequency",
    palette=cmap,
    sizes=(150, 320)
)
g.despine(left=True, bottom=True)
g.fig.set_size_inches(12,7)
g._legend.set_title('Frecuencia de apariciones')
plt.title('Salarios Vs Lenguaje de Programación',fontsize=20)
plt.ylabel('Salarios Brutos (Mediana)',fontsize=15)
plt.xlabel('Top Lenguajes Programación',fontsize=15)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# En el anterior gráfico, podemos observar en el eje de las "y" una escala de valores correspondientes al rango de los salarios brutos obtenidos para cada uno de los top lenguajes de programación (eje de las x), elegidos dentro de los desarrolladores/programadores con trabajos fulltime.
#
# El tamaño de los puntos y su degradez de colores, representan la cantidad de apariciones dentro de nuestro dataset filtrado. Cuanto más oscuro sea el color, más son las personas que lo utilizan.
#
# De esta forma podemos visualizar, los lenguajes de programación que representan los mejores salarios del dataset.

# %% [markdown]
# ---

# %%
Marge_df
# Out:
#    programming_language  frequency  salary_monthly_BRUTO
# 0            Javascript       1228               90000.0
# 1                  Java        647              105000.0
# 2            TypeScript        440              100000.0
# 3                  .NET        374               85000.0
# 4                    C#        360               85800.0
# 5                   PHP        307               81000.0
# 6                Python        289              100000.0
# 7                Kotlin         98              130000.0
# 8                   C++         67               85000.0
# 9                   VBA         59               80914.8
# 10                    C         57               85000.0
# 11                 Ruby         32              102000.0

# %%
Marge_df['frequency'].sum()
# Out:
# 3958

# %%
fig = plt.figure(figsize=(12,7))
rect1 = plt.bar(Marge_df['programming_language'], Marge_df['frequency'].sum(),
                width=0.5, color='#1f77b4')
rect2 = plt.bar(Marge_df['programming_language'] ,Marge_df['frequency'],
                width=0.5, color='lightblue')

# %%
filtered_df_lang[filtered_df_lang.programming_language.isin(['Ruby'])]
# Out:
#      programming_language work_contract_type  work_role  \
# 156                  Ruby          Full-Time  Developer
# 191                  Ruby          Full-Time  Developer
# 206                  Ruby          Full-Time  Developer
# 367                  Ruby          Full-Time  Developer
# 517                  Ruby          Full-Time  Developer
# 542                  Ruby          Full-Time  Developer
# 557                  Ruby          Full-Time  Developer
# 951                  Ruby          Full-Time  Developer
# 984                  Ruby          Full-Time  Developer
# 1105                 Ruby          Full-Time  Developer
# 1180                 Ruby          Full-Time  Developer
# 1482                 Ruby          Full-Time  Developer
# 1754                 Ruby          Full-Time  Developer
# 1812                 Ruby          Full-Time  Developer
# 1885                 Ruby          Full-Time  Developer
# 1936                 Ruby          Full-Time  Developer
# 1991                 Ruby          Full-Time  Developer
# 2048                 Ruby          Full-Time  Developer
# 2264                 Ruby          Full-Time  Developer
# 2387                 Ruby          Full-Time  Developer
# 2487                 Ruby          Full-Time  Developer
# 2505                 Ruby          Full-Time  Developer
# 2542                 Ruby          Full-Time  Developer
# 2607                 Ruby          Full-Time  Developer
# 2762                 Ruby          Full-Time  Developer
# 2959                 Ruby          Full-Time  Developer
# 3308                 Ruby          Full-Time  Developer
# 3378                 Ruby          Full-Time  Developer
# 4397                 Ruby          Full-Time  Developer
# 4741                 Ruby          Full-Time  Developer
# 4816                 Ruby          Full-Time  Developer
# 5823                 Ruby          Full-Time  Developer
#
#                         tools_programming_languages  salary_monthly_BRUTO  \
# 156                    Java, PHP, Python, Ruby, SQL              90000.00
# 191               CSS, HTML, Java, Javascript, Ruby             108000.00
# 206                         HTML, Java, Ruby, Scala             234000.00
# 367                            Go, Javascript, Ruby             124000.00
# 517                    Javascript, Ruby, TypeScript             306000.00
# 542   Bash/Shell, Go, Groovy, HTML, Java, Ruby, SQL             101000.00
# 557                                            Ruby             147200.00
# 951                                            Ruby             200000.00
# 984                     CSS, HTML, Javascript, Ruby              80000.00
# 1105                         HTML, Javascript, Ruby              90000.00
# 1180                           Ruby, Smalltalk, SQL              90000.00
# 1482                 Java, Javascript, Kotlin, Ruby             137790.00
# 1754                          Javascript, Ruby, SQL              59103.00
# 1812                    HTML, Javascript, Ruby, SQL             110000.00
# 1885        HTML, Javascript, Ruby, SQL, TypeScript             110000.00
# 1936               CSS, HTML, Javascript, Ruby, SQL             243676.00
# 1991                               Javascript, Ruby              47080.72
# 2048                                .NET, Ruby, SQL              47080.00
# 2264                                           Ruby              45000.00
# 2387                                           Ruby             315000.00
# 2487               CSS, HTML, Javascript, Ruby, SQL              93500.00
# 2505                               Javascript, Ruby             166000.00
# 2542                               Javascript, Ruby              47175.00
# 2607          CSS, HTML, Javascript, PHP, Ruby, SQL              75000.00
# 2762                               Javascript, Ruby             360000.00
# 2959                         Java, Javascript, Ruby             110000.00
# 3308             Bash/Shell, Java, Javascript, Ruby              90000.00
# 3378                   Bash/Shell, Javascript, Ruby              40000.00
# 4397                    HTML, Javascript, Ruby, SQL             178000.00
# 4741                                   Python, Ruby              77000.00
# 4816         CSS, HTML, Java, Javascript, Ruby, SQL             103000.00
# 5823                                           Ruby              65576.00
#
#       salary_monthly_NETO  profile_years_experience  work_years_in_company  \
# 156               70000.0                       7.0                    2.0
# 191               85000.0                       6.0                    0.0
# 206              170000.0                      10.0                    3.0
# 367               91000.0                       2.0                    0.0
# 517              202380.0                       5.0                    2.0
# 542               76000.0                       3.0                    1.0
# 557              108000.0                       2.5                    0.0
# 951              180000.0                       4.0                    0.0
# 984               65000.0                       3.0                    3.0
# 1105              66000.0                       3.0                    3.0
# 1180              75000.0                      11.0                    1.0
# 1482              98000.0                       5.0                    2.0
# 1754              49056.0                       2.5                    2.5
# 1812              68000.0                       6.0                    4.0
# 1885              76000.0                       6.0                    3.0
# 1936             127000.0                      13.0                   13.0
# 1991              39077.0                       0.0                    0.0
# 2048              39077.0                       0.0                    0.0
# 2264              39000.0                       1.0                    1.0
# 2387             252000.0                      12.0                    0.0
# 2487              62000.0                       5.0                    3.0
# 2505             100000.0                       8.0                    8.0
# 2542              45000.0                       8.0                    3.0
# 2607              65000.0                       3.0                    2.0
# 2762             320000.0                       4.0                    0.0
# 2959              83300.0                       4.0                    1.0
# 3308              50000.0                       0.0                    0.0
# 3378                  NaN                       0.0                    0.0
# 4397             118000.0                       4.5                    2.0
# 4741              55000.0                       0.0                    0.0
# 4816             100000.0                       7.0                    1.0
# 5823              52789.0                       3.0                    3.0
#
#       work_years_in_current_position  work_people_in_charge_of
# 156                              1.0                         3
# 191                              0.0                         0
# 206                              3.0                         0
# 367                              0.0                         0
# 517                              2.0                         0
# 542                              1.0                         0
# 557                              0.0                         0
# 951                              0.0                         0
# 984                              3.0                         0
# 1105                             3.0                         0
# 1180                             1.0                         0
# 1482                             0.0                         0
# 1754                             1.0                         0
# 1812                             4.0                         0
# 1885                             6.0                         1
# 1936                             4.0                         0
# 1991                             0.0                         0
# 2048                             0.0                         0
# 2264                             1.0                         0
# 2387                             0.0                         0
# 2487                             1.0                         0
# 2505                             3.0                         0
# 2542                             3.0                         1
# 2607                             2.0                         0
# 2762                             0.0                         0
# 2959                             1.0                         0
# 3308                             0.0                         1
# 3378                             0.0                         0
# 4397                             2.0                         0
# 4741                             0.0                         0
# 4816                             1.0                         3
# 5823                             2.0                         0

# %% [markdown]
# Pre-Conclusión

# %%
fig = plt.figure(figsize=(10,8))
seaborn.countplot(data=filtered_df_lang, y='programming_language', color = "red", order = filtered_df_lang['programming_language'].value_counts().index) 
plt.xticks(rotation=45)
plt.ylabel("Frecuencia de apariciones")
plt.xlabel("Lenguaje")
plt.title('Top Lenguajes de Programación',fontsize=20)
plt.show()

# %% [markdown]
# ## Conclusión

# %% [markdown]
# Pregunta:
# > ¿Cuáles son los lenguajes de programación asociados a los mejores salarios?

# %% [markdown]
# Según nuestro análisis sobre los datos, podemos remarcar lo siguiente:

# %% [markdown]
# > * Entre los Lenguajes de Programación mejor pago, se encuentran aquellos que manejan "Bash/Shell" con pocas personas que lo utilizan, y sigue "Java" en segundo lugar, con un poco más de usuarios que lo manejan.
# > * Entre los Lenguajes de Programación más usados, se encuentra JavaScript pero eso no quiere decir, que sea el mejor pago, ya que por encima tiene 3 lenguajes con mejor remuneración.

# %% [markdown]
# # Ejercicio 2 - Densidades y varias varialbes
#
# Responder a la pregunta general: **¿Que herramientas (prácticas y teóricas) són útiles para explorar la base, descubrir patrones, asociaciones?**
#
# Para ello considere (igual al ejercicio Anterior):
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en sub-poblaciones.

# %% [markdown]
# 1 - Teniendo encuenta el analisis del ejercicio 1 seleccionaremos las columnas relevantes para analizar, entre ellas estan:
# profile_studies_level,
# profile_studies_level_state,
# salary_in_usd,
# work_contract_type,
# salary_monthly_NETO

# %%
col_relevantes = ['salary_monthly_NETO','salary_monthly_BRUTO', 'profile_age', 'work_contract_type', 'salary_in_usd', 'profile_studies_level', 'profile_studies_level_state','profile_years_experience','profile_open_source_contributions']

# %% [markdown]
# 2 -  Se procedio a eliminar los valores NaN y erroneos del dataset, tambien se liminaron los valores extremos en la columna salario neto y bruto.
# Para las columnas edad se eliminaron las personas con de 100 años.

# %%
df.dropna(subset=['salary_monthly_NETO'], inplace=True)
df.dropna(subset=['salary_monthly_BRUTO'], inplace=True)
df = df[df['salary_monthly_NETO'] > 10000]
df = df[df['salary_monthly_BRUTO'] > 10000]
max_salary = df['salary_monthly_NETO'].quantile(0.99)
max_salary_bruto = df['salary_monthly_BRUTO'].quantile(0.99)
df = df[df['salary_monthly_NETO'] < max_salary]
df = df[df['salary_monthly_BRUTO'] < max_salary_bruto]
df = df[df['profile_age'] < 65]

# %%
df = df[col_relevantes]
df
# Out:
#       salary_monthly_NETO  salary_monthly_BRUTO  profile_age  \
# 1                 63000.0               79000.0           29
# 3                102000.0              130000.0           39
# 4                106000.0              140000.0           32
# 5                 44000.0               54000.0           25
# 6                 62400.0               75000.0           33
# ...                   ...                   ...          ...
# 6086              82000.0              120000.0           52
# 6087             120000.0              150000.0           43
# 6088              56450.0               69000.0           32
# 6089             130000.0              180000.0           32
# 6090              97000.0               99000.0           37
#
#      work_contract_type salary_in_usd profile_studies_level  \
# 1             Full-Time           NaN         Universitario
# 3             Full-Time           NaN              Posgrado
# 4             Full-Time           NaN         Universitario
# 5             Full-Time           NaN             Terciario
# 6             Full-Time           NaN         Universitario
# ...                 ...           ...                   ...
# 6086          Full-Time           NaN         Universitario
# 6087          Full-Time           NaN         Universitario
# 6088          Full-Time           NaN            Secundario
# 6089          Full-Time           NaN         Universitario
# 6090          Full-Time           NaN             Terciario
#
#      profile_studies_level_state  profile_years_experience  \
# 1                       En curso                       5.0
# 3                     Incompleto                      15.0
# 4                       En curso                       9.0
# 5                     Incompleto                       1.0
# 6                     Incompleto                       1.0
# ...                          ...                       ...
# 6086                  Incompleto                      23.0
# 6087                  Incompleto                      25.0
# 6088                  Completado                      13.0
# 6089                  Completado                      10.0
# 6090                  Completado                      13.0
#
#      profile_open_source_contributions
# 1                                   No
# 3                                   Sí
# 4                                   No
# 5                                   No
# 6                                   Sí
# ...                                ...
# 6086                                No
# 6087                                Sí
# 6088                                No
# 6089                                No
# 6090                                No
#
# [4639 rows x 9 columns]

# %% [markdown]
# ya tenemos el data set listo para ser analizado.

# %% [markdown]
# ## a) Densidad conjunta
#
# Que herramientas visuales y modelos puede utilizar para estudiar la distribución y comportamiento de sus datos?
#
# Elija tres variables numéricas y 2 variables categóricas. Visualice la base según varias de las variables elegidas. Puede describir de alguna forma el comportamiento de sus datos? Que herramientas utilizaría? Describa

# %% [markdown]
# Variables numericas: salary_monthly_NETO y profile_age
# Variables categoricas: work_contract_type y salary_in_usd
#
# Para estudiar variables cateogircas podemos utilizar ???????
# Para estudiar variables numericas podemos utilizar ???????

# %%
plot = df['work_contract_type'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='Tipo de contratación')

# %%
#Para un mejor analisis convertiremos la columna salario en dolares en verdaderos o falsos
df['salary_in_usd2'] = df['salary_in_usd'].notna()

# %%
plot = df['salary_in_usd2'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='Tipo de Pago')

# %%
seaborn.pairplot(data=df,
                 x_vars='profile_age',
                 y_vars='salary_monthly_NETO',
                 hue='work_contract_type',
                 aspect=2, height=4);

# %%
seaborn.set(rc = {'figure.figsize':(20,8)})
seaborn.swarmplot( x='work_contract_type',
                y='salary_monthly_NETO',
                hue='salary_in_usd2', data=df, size=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 89.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 52.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 18.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Podemos observar como el salario con respecto a la edad y el tipo de contrato varia.
# ##----- no se que mas poner no tengo chamuyo

# %% [markdown]
# ## b) Asociación
#
# Necesitamos decidir si sacar o no la columna de salario bruto, para hacer la encuesta más simple.
# ¿Existe una correlación entre el salario bruto y el salario neto? ¿Qué abordaje y medidas utilizaría?

# %%
seaborn.pairplot(data=df,
                 x_vars='salary_monthly_NETO',
                 y_vars='salary_monthly_BRUTO',
                 aspect=2, height=4);

# %%
df[['salary_monthly_NETO', 'salary_monthly_BRUTO']].corr()
# Out:
#                       salary_monthly_NETO  salary_monthly_BRUTO
# salary_monthly_NETO              1.000000              0.946546
# salary_monthly_BRUTO             0.946546              1.000000

# %% [markdown]
# El grafico nos permite visualizar una correlacion entre salario neto y bruto, la dispercion de puntos se asemeja a una recta y en la tabla de correlacion podemos observar que ambos  obtienen un valor cercano a 1, lo que nos hace entender que existe una correlacion

# %% [markdown]
# ## c) Densidad condicional
#
# Estudie la distribución del salario según el nivel de estudio.
#
# Separe la población según el nivel de estudio (elija **dos** subpoblaciones numerosas), y grafique de manera comparativa ambos histogramas de la variable `salary_monthly_NETO`.
# ¿Considera que ambas variables son independientes?
# ¿Qué analizaría al respecto?
#
# Calcule medidas de centralización y dispersión para cada subpoblación.

# %%
seaborn.boxplot(data=df,
                x= 'profile_studies_level', 
                y='salary_monthly_NETO',
                hue='profile_studies_level_state',
                order = [ 'Primario', 'Secundario', 'Terciario', 'Universitario', 'Posgrado', 'Doctorado', 'Posdoctorado']);

# %%
agrupacion_x_nivel = {
    'Primario': 'No Universitario',
    'Secundario': 'No Universitario',
    'Terciario': 'No Universitario',
    'Universitario': 'Universitario',
    'Posgrado': 'Universitario',
    'Doctorado': 'Universitario',
    'Posdoctorado': 'Universitario'
}
estudios = df['profile_studies_level'].replace(agrupacion_x_nivel)

# %%
seaborn.histplot(df,
                 x='salary_monthly_NETO',
                 hue=estudios,
                 hue_order = ['No Universitario','Universitario']);

# %% [markdown]
# ## d) Densidad conjunta condicional
#
# Elija dos variables **numéricas** y una variable **categórica**.
# Estudie la dispersión (*scatterplot*) de las dos variables numéricas, discriminando en color por la variable categórica (**hue** en *seaborn*).

# %%
#['salary_monthly_NETO','salary_monthly_BRUTO', 'profile_age', 'work_contract_type', 'salary_in_usd', 'profile_studies_level', 'profile_studies_level_state','profile_years_experience']


seaborn.scatterplot(data=df.sample(500),
                    x='profile_years_experience',
                    y='salary_monthly_NETO',
                    hue='profile_open_source_contributions');

# %% [markdown]
# Variables Numéricas: `salary_monthly_NETO` y `profile_years_experience`.Variables Categóricas: `profile_open_source_contributions`
